# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
b = [20.9, 24.1, 27.5, 31, 34.5, 37.8, 41, 43.8, 46.2,
48.4, 50.2, 51.7, 53.1, 54.2, 55, 55.8, 56.4, 56.9, 57, 
57.2, 57.3, 57.5, 57.6, 57.7, 57.8, 57.9, 58, 58.1, 58]

d = [0, 2.5, 5, 7.5, 10, 12.5, 15, 17.5, 20, 22.5, 25,
27.5, 30, 32.5, 35, 37.5, 40, 42.5, 43.5, 44.5, 46.5,
47.5, 48.5, 49.5, 50.5, 51.5, 52.5, 57.5, 65 ]

# %%
b = np.array(b)
d = np.array(d)

# %%
plt.figure(figsize=(24, 12))
plt.plot(d, b, label='campo', linewidth=1.8, color = 'brown')
plt.scatter(d, b, label='campo', zorder=2)
plt.grid()
plt.legend()
plt.xlabel('Distância dentro do Magneto (mm)')
plt.ylabel('Intensidade do Campo Magnético Axial (G)')
plt.title('Mapeamento do Campo Magnético dentro do Magneto')
plt.show()
